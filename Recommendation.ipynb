# %% [markdown]
# #Installing all dependent libraries

# %%
# %pip install numpy
# %pip install pandas
# %pip install sklearn
# %pip install seaborn
# Out:
# Requirement already satisfied: numpy in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.22.4)
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from sklearn) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.8.1)
# Requirement already satisfied: joblib>=1.0.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=2a43b384b11e993fe96c50865de6d79213366d9a685b5e2a002cb4bb77ee6f97
#   Stored in directory: /home/gitpod/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 13.1 MB/s eta 0:00:00
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.5.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 165.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.23 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: scipy>=1.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.8.1)
# Requirement already satisfied: numpy>=1.15 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from seaborn) (1.22.4)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 170.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.3-py3-none-any.whl (930 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.9/930.9 kB 164.3 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/gitpod/.pyenv/versions/3.8.13/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib, seaborn
# Successfully installed cycler-0.11.0 fonttools-4.33.3 kiwisolver-1.4.2 matplotlib-3.5.2 seaborn-0.11.2
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing all dependent libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
#Reading the csv file spotify data set and preprocessing the dataset according to required features

# %%
data = pd.read_csv('spotify_songs.csv')
data = data[data['language'] == 'en']
data.drop(columns=['language', 'playlist_name', 'playlist_id'], inplace=True)
data = data.drop_duplicates(subset=['track_name', 'track_artist'])
data['track_album_release_date'] = pd.to_datetime(data['track_album_release_date'], infer_datetime_format=True)
data = data.sort_values(by=['track_album_release_date'])
data.reset_index(drop=True, inplace=True)
print(data.columns)
songs_count = data.shape[0]
print(songs_count)
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'lyrics', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_genre', 'playlist_subgenre', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'duration_ms'],
#       dtype='object')
# 13726

# %%
#Sectioning off data for recommendation subsystem

# %%
lyrics_data = data['lyrics']
energy_data = data[['danceability', 'tempo', 'acousticness']]
mood_data = data[['mode', 'key', 'valence']]

# %%
#Using cosine similarity and Tfidf for making lyrics comparable

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

lyric_vectorizer = TfidfVectorizer(stop_words='english')
lyrics_data = lyric_vectorizer.fit_transform(lyrics_data)
lyric_similarity_matrix = cosine_similarity(lyrics_data)

# %%
#Using euclidean distance for making energy and mood comparable

# %%
from sklearn.metrics.pairwise import euclidean_distances

energy_difference_matrix = euclidean_distances(energy_data)
mood_difference_matrix = euclidean_distances(mood_data)

# %%
#Utility functions

# %%
def sort_by_popularity(songs, descending=True):
    if descending:
        return songs.sort_values(by=['track_popularity'])[::-1]
    else:
        return songs.sort_values(by=['track_popularity'])


def get_similar(track_index, count, comparison_matrix, select_smallest):
    similar_songs_indexes = np.argsort(np.array(comparison_matrix[track_index]))
    similar_songs_indexes = np.delete(similar_songs_indexes, np.where(similar_songs_indexes == track_index))
    similar_songs_indexes = similar_songs_indexes[:count] if select_smallest else similar_songs_indexes[::-1][:count]
    return data.iloc[similar_songs_indexes].copy()


def songs_as_dict(songs, include_fields):
    return songs[include_fields].to_dict(orient='index')


def get_closest_n(track_index, count):
    if track_index >= count//2 and track_index < songs_count-count//2:
        return pd.concat([data.iloc[track_index-count//2 : track_index], data.iloc[track_index+1 : track_index+count//2+1]])
    elif track_index < count//2:
        return data.head(count+1).drop(track_index)
    else:
        return data.tail(count+1).drop(track_index)

# %%
#Getters for recommendation subsystems

# %%
def get_by_same_artist(track_index, count):
    return data[data['track_artist'] == data.iloc[track_index]['track_artist']].drop(track_index)[:count]


def get_lyrically_similar(track_index, count):
    return get_similar(track_index, count, lyric_similarity_matrix, False)


def get_energy_similar(track_index, count):
    return get_similar(track_index, count, energy_difference_matrix, True)


def get_mood_similar(track_index, count):
    return get_similar(track_index, count, mood_difference_matrix, True)


def get_random(count):
    return data.sample(count)


def get_released_around_same_time(track_index, count):
    return get_closest_n(track_index, count)

# %%
def recommend_by_same_artist(track_index, count, prioritisePopular):
    songs_by_same_artist = get_by_same_artist(track_index, count)
    songs_by_same_artist['recommendation_type'] = 'by same artist'
    return sort_by_popularity(songs_by_same_artist, prioritisePopular)


def recommend_lyrically_similar(track_index, count, prioritisePopular):
    similar_songs = get_lyrically_similar(track_index, count)
    similar_songs['recommendation_type'] = 'lyrically similar'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_energy_similar(track_index, count, prioritisePopular):
    similar_songs = get_energy_similar(track_index, count)
    similar_songs['recommendation_type'] = 'similar energy'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_mood_similar(track_index, count, prioritisePopular):
    similar_songs = get_mood_similar(track_index, count)
    similar_songs['recommendation_type'] = 'similar mood'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_released_around_same_time(track_index, count, prioritisePopular):
    contemporary_songs = get_released_around_same_time(track_index, count)
    contemporary_songs['recommendation_type'] = 'released around same time'
    return sort_by_popularity(contemporary_songs, prioritisePopular)


def recommend_random(count, prioritisePopular):
    random_songs = get_random(count)
    random_songs['recommendation_type'] = 'random'
    return sort_by_popularity(random_songs, prioritisePopular)

# %%
#Recommendation Subsystem

# %%
def recommend_by_same_artist(track_index, count, prioritisePopular):
    songs_by_same_artist = get_by_same_artist(track_index, count)
    songs_by_same_artist['recommendation_type'] = 'by same artist'
    return sort_by_popularity(songs_by_same_artist, prioritisePopular)


def recommend_lyrically_similar(track_index, count, prioritisePopular):
    similar_songs = get_lyrically_similar(track_index, count)
    similar_songs['recommendation_type'] = 'lyrically similar'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_energy_similar(track_index, count, prioritisePopular):
    similar_songs = get_energy_similar(track_index, count)
    similar_songs['recommendation_type'] = 'similar energy'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_mood_similar(track_index, count, prioritisePopular):
    similar_songs = get_mood_similar(track_index, count)
    similar_songs['recommendation_type'] = 'similar mood'
    return sort_by_popularity(similar_songs, prioritisePopular)


def recommend_released_around_same_time(track_index, count, prioritisePopular):
    contemporary_songs = get_released_around_same_time(track_index, count)
    contemporary_songs['recommendation_type'] = 'released around same time'
    return sort_by_popularity(contemporary_songs, prioritisePopular)


def recommend_random(count, prioritisePopular):
    random_songs = get_random(count)
    random_songs['recommendation_type'] = 'random'
    return sort_by_popularity(random_songs, prioritisePopular)

# %%
def hybrid_recommend(track_index, count=6, prioritisePopular=True):
    by_same_artist = recommend_by_same_artist(track_index, count, prioritisePopular)
    lyrically_similar = recommend_lyrically_similar(track_index, count, prioritisePopular)
    energy_similar = recommend_energy_similar(track_index, count, prioritisePopular)
    mood_similar = recommend_mood_similar(track_index, count, prioritisePopular)
    random = recommend_random(count, prioritisePopular)
    released_around_same_time = recommend_released_around_same_time(track_index, count, prioritisePopular)
    all_recommendations = pd.concat([by_same_artist, lyrically_similar, energy_similar, mood_similar, random, released_around_same_time]).drop_duplicates()
    return songs_as_dict(all_recommendations, include_fields=['track_name', 'track_artist', 'recommendation_type'])

hybrid_recommend(4982)
# Out:
# {5826: {'track_name': 'I Knew You Were Trouble.',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  5827: {'track_name': 'We Are Never Ever Getting Back Together',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  4136: {'track_name': 'Our Song',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  4686: {'track_name': 'You Belong With Me',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  5829: {'track_name': 'I Knew You Were Trouble',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  5556: {'track_name': '22',
#   'track_artist': 'Taylor Swift',
#   'recommendation_type': 'by same artist'},
#  7816: {'track_name': 'What Do You Mean?',
#   'track_artist': 'Justin Bieber',
#   'recommendation_type': 'lyrically similar'},
#  6697: {'track_name': 'I Mean It (feat. Remo)',
#   'track_artist': 'G-Eazy',
#   'recommendation_type': 'lyrically similar'},
#  11972: {'track_name': 'Do You Mean (feat. Ty Dolla $ign & bülow) - Myon Remix',
#   'track_artist': 'The Chainsmokers',
#   'recommendation_type': 'lyrically similar'},
#  12305: {'track_name': 'Do You Mean (feat. Ty Dolla $ign & bülow)',
#   'track_artist': 'The Chainsmokers',
#   'recommendation_type': 'lyrically similar'},
#  12095: {'track_name': 'Diggid',
#   'track_artist': 'TYNAN',
#   'recommendation_type': 'lyrically similar'},
#  8703: {'track_name': 'I Hope You Know',
#   'track_artist': 'bLAck pARty',
#   'recommendation_type': 'lyrically similar'},
#  4254: {'track_name': 'Better in Time',
#   'track_artist': 'Leona Lewis',
#   'recommendation_type': 'similar energy'},
#  13035: {'track_name': 'Write It Down',
#   'track_artist': 'Hamzaa',
#   'recommendation_type': 'similar energy'},
#  2316: {'track_name': 'Last Night',
#   'track_artist': 'Az Yet',
#   'recommendation_type': 'similar energy'},
#  2828: {'track_name': 'Everything',
#   'track_artist': 'Jody Watley',
#   'recommendation_type': 'similar energy'},
#  10540: {'track_name': "God's Work",
#   'track_artist': 'Demun Jones',
#   'recommendation_type': 'similar energy'},
#  8486: {'track_name': 'Loser',
#   'track_artist': 'The Cleverlys',
#   'recommendation_type': 'similar energy'},
#  1050: {'track_name': 'Walk Of Life',
#   'track_artist': 'Dire Straits',
#   'recommendation_type': 'similar mood'},
#  5515: {'track_name': 'Tonight Tonight',
#   'track_artist': 'Hot Chelle Rae',
#   'recommendation_type': 'similar mood'},
#  1683: {'track_name': "Don't Sweat The Technique",
#   'track_artist': 'Eric B. & Rakim',
#   'recommendation_type': 'similar mood'},
#  10428: {'track_name': 'Fbgm',
#   'track_artist': 'Ramirez',
#   'recommendation_type': 'similar mood'},
#  3303: {'track_name': 'Screwed Up',
#   'track_artist': 'Ludacris',
#   'recommendation_type': 'similar mood'},
#  2630: {'track_name': 'Biggie/Tupac Live Freestyle (Funkmaster Flex & Big Kap Feat. DJ Mister Cee, Notorious B.I.G & Tupac)',
#   'track_artist': 'Funkmaster Flex',
#   'recommendation_type': 'similar mood'},
#  7862: {'track_name': 'Me, Myself & I',
#   'track_artist': 'G-Eazy',
#   'recommendation_type': 'random'},
#  5261: {'track_name': 'Starships',
#   'track_artist': 'Nicki Minaj',
#   'recommendation_type': 'random'},
#  5414: {'track_name': 'So In Love - feat. Anthony Hamilton',
#   'track_artist': 'Jill Scott',
#   'recommendation_type': 'random'},
#  10097: {'track_name': 'I Know You - Vigiland Remix',
#   'track_artist': 'Craig David',
#   'recommendation_type': 'random'},
#  11687: {'track_name': 'Step Back (VIP Mix)',
#   'track_artist': 'Chocolate Puma',
#   'recommendation_type': 'random'},
#  5783: {'track_name': 'Home',
#   'track_artist': 'Teitur',
#   'recommendation_type': 'random'},
#  4985: {'track_name': 'Over',
#   'track_artist': 'Drake',
#   'recommendation_type': 'released around same time'},
#  4983: {'track_name': 'Shades',
#   'track_artist': 'Christopher Wilde',
#   'recommendation_type': 'released around same time'},
#  4984: {'track_name': 'Tyrone',
#   'track_artist': 'Erykah Badu',
#   'recommendation_type': 'released around same time'},
#  4981: {'track_name': 'Hard To Swallow',
#   'track_artist': 'You Me At Six',
#   'recommendation_type': 'released around same time'},
#  4979: {'track_name': 'Make a Movie',
#   'track_artist': 'Jasmine Sagginario',
#   'recommendation_type': 'released around same time'},
#  4980: {'track_name': 'Eenie Meenie',
#   'track_artist': 'Justin Bieber',
#   'recommendation_type': 'released around same time'}}

# %%
# testing / visualization
data[data['track_artist'] == 'Taylor Swift']

# data.iloc[2274]

# sb.displot(data=data, x='track_album_release_date')
# data[data['track_artist'] == 'Queen'].head(30)
# sonic_data.describe()

# data['track_artist'].value_counts()
# Out:
#                      track_id  \
# 4136   43H3q2NWT9LCuYS1B5IUvV
# 4686   7G6TDmGJXDoBaV6NGj3Yic
# 4982   0KztjtD3ytzgYjUKIVfBnW
# 5556   1mQRQlbf1nXbazPEuSyij8
# 5826   6FB3v4YcR57y4tXFcdxI1E
# 5827   0VwNdo84DaVYLIkbVO86ND
# 5829   6RjKVXi31fui9m4dbiGRrL
# 6389   1u8c2t2Cy7UBoG4ArRcF5g
# 6917   5WfhXulggG0c6WoVeMPA8N
# 6918   273dCMFseLcVsoSWx59IoE
# 6923   59HjlYCeBsxdI0fcm3zglw
# 9884   1JbR9RDP3ogVNEWFgNXAjh
# 9886   12WvaS3V4dPRBU2o37vX69
# 9889   5sOch9Cf4uxcMtwFzMtNqQ
# 9897   2x0WlnmfG39ZuDmstl9xfX
# 9970   1Ygm9KdH3wbzDekO8JgxcW
# 11778  4Sib57MmYGJzSvkW84jTwh
# 12481  7Bjf96uNizpvXLvNyOJpst
# 12495  6RRNNciQGZEXnqk8SQ9yv5
# 12523  43rA71bccXFGD4C8GOpIlN
# 13189  3i9UVldZOE0aD0JnyfAZZ0
#
#                                             track_name  track_artist  \
# 4136                                          Our Song  Taylor Swift
# 4686                                You Belong With Me  Taylor Swift
# 4982                                              Mean  Taylor Swift
# 5556                                                22  Taylor Swift
# 5826                          I Knew You Were Trouble.  Taylor Swift
# 5827           We Are Never Ever Getting Back Together  Taylor Swift
# 5829                           I Knew You Were Trouble  Taylor Swift
# 6389                                       Blank Space  Taylor Swift
# 6917                                      Shake It Off  Taylor Swift
# 6918                                         Bad Blood  Taylor Swift
# 6923                                    Wildest Dreams  Taylor Swift
# 9884                          Look What You Made Me Do  Taylor Swift
# 9886                                          Gorgeous  Taylor Swift
# 9889                                          Delicate  Taylor Swift
# 9897                                          End Game  Taylor Swift
# 9970                ...Ready For It? - BloodPop® Remix  Taylor Swift
# 11778  ME! (feat. Brendon Urie of Panic! At The Disco)  Taylor Swift
# 12481       You Need To Calm Down - Clean Bandit Remix  Taylor Swift
# 12495                            You Need To Calm Down  Taylor Swift
# 12523                        I Forgot That You Existed  Taylor Swift
# 13189               Lover (Remix) [feat. Shawn Mendes]  Taylor Swift
#
#                                                   lyrics  track_popularity  \
# 4136   I was riding shotgun with my hair undone In th...                61
# 4686   You're on the phone with your girlfriend, she'...                52
# 4982   You, with your words like knives And swords an...                62
# 5556   It feels like a perfect night To dress up like...                 0
# 5826   NA Once upon a time, a few mistakes ago I was ...                76
# 5827   I remember when we broke up the first time Say...                74
# 5829   NA Once upon a time, a few mistakes ago I was ...                16
# 6389   Nice to meet you, where you been? I could show...                78
# 6917   I stay out too late Got nothing in my brain Th...                18
# 6918   'Cause baby, now we've got bad blood You know ...                62
# 6923   He said, "Let's get out of this town Drive out...                65
# 9884   I don't like your little games Don't like your...                74
# 9886   Gorgeous You should take it as a compliment Th...                67
# 9889   This ain't for the best My reputation's never ...                71
# 9897   I wanna be your end game I wanna be your first...                68
# 9970   Knew he was a killer first time that I saw him...                50
# 11778  I promise that you'll never find another like ...                29
# 12481  You are somebody that I don't know But you're ...                54
# 12495  You are somebody that I don't know But you're ...                86
# 12523  How many days did I spend thinking 'Bout how y...                79
# 13189  We could leave the Christmas lights up 'til Ja...                85
#
#                track_album_id  \
# 4136   2rU7u7C2v5i45MFVxx7xG1
# 4686   08CWGiv27MVQhYpuTtvx83
# 4982   6Ar2o9KCqcyYF9J0aQP3au
# 5556   092fm0yKd9V4VGi6G3u51Y
# 5826   4jTYApZPMapg56gRycOn0D
# 5827   4jTYApZPMapg56gRycOn0D
# 5829   5FerdPFXSHSnCVq4OBy4Ey
# 6389   1yGbNOtRIgdIiGHOEBaZWf
# 6917   6w36pmMA5bxECalu5rxQAw
# 6918   2QJmrSgbdM35R67eoGQo4j
# 6923   2QJmrSgbdM35R67eoGQo4j
# 9884   1Hrs3jLGexOvBoaPMoOQYJ
# 9886   1Hrs3jLGexOvBoaPMoOQYJ
# 9889   1Hrs3jLGexOvBoaPMoOQYJ
# 9897   6DEjYFkNZh67HP7R9PSZvv
# 9970   45fMDoh9dhhQicddIZzhKM
# 11778  0WGakTFs8cnggcYsHjIhgy
# 12481  531nfs5NPsmkRC1LJb1cdj
# 12495  1NAmidJlEaVgA3MpcPFYGq
# 12523  1NAmidJlEaVgA3MpcPFYGq
# 13189  2UfvnX1YYeC2cExMQTMbXC
#
#                                        track_album_name  \
# 4136   Taylor Swift (Big Machine Radio Release Special)
# 4686                   Fearless (International Version)
# 4982                                          Speak Now
# 5556                                                 22
# 5826            Red (Big Machine Radio Release Special)
# 5827            Red (Big Machine Radio Release Special)
# 5829                                                Red
# 6389                                      1989 (Deluxe)
# 6917                                               1989
# 6918                                               1989
# 6923                                               1989
# 9884     reputation (Big Machine Radio Release Special)
# 9886     reputation (Big Machine Radio Release Special)
# 9889     reputation (Big Machine Radio Release Special)
# 9897                                         reputation
# 9970                 ...Ready For It? (BloodPop® Remix)
# 11778                                               ME!
# 12481        You Need To Calm Down (Clean Bandit Remix)
# 12495                                             Lover
# 12523                                             Lover
# 13189                Lover (Remix) [feat. Shawn Mendes]
#
#       track_album_release_date playlist_genre playlist_subgenre  ...  key  \
# 4136                2006-10-23            pop     post-teen pop  ...    2
# 4686                2008-11-11          latin     latin hip hop  ...    6
# 4982                2010-01-01            pop     post-teen pop  ...    4
# 5556                2012-01-01            pop     post-teen pop  ...    7
# 5826                2012-10-21            pop     post-teen pop  ...    3
# 5827                2012-10-21            pop     post-teen pop  ...    7
# 5829                2012-10-22          latin     latin hip hop  ...    6
# 6389                2014-01-01            pop     post-teen pop  ...    5
# 6917                2014-10-27            pop        electropop  ...    7
# 6918                2014-10-27            edm           pop edm  ...    7
# 6923                2014-10-27          latin     latin hip hop  ...    8
# 9884                2017-11-08            pop     post-teen pop  ...    9
# 9886                2017-11-08            pop     post-teen pop  ...    7
# 9889                2017-11-08            edm           pop edm  ...    9
# 9897                2017-11-10            r&b           hip pop  ...    2
# 9970                2017-12-01            edm           pop edm  ...    7
# 11778               2019-04-26            pop   indie poptimism  ...    0
# 12481               2019-08-20            edm           pop edm  ...    2
# 12495               2019-08-23            pop     post-teen pop  ...    2
# 12523               2019-08-23            r&b           hip pop  ...    5
# 13189               2019-11-13            pop         dance pop  ...    7
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 4136     -4.932     1       0.0298       0.11300          0.000000    0.3250
# 4686     -4.436     1       0.0381       0.15100          0.000020    0.1040
# 4982     -3.978     1       0.0426       0.44500          0.000000    0.2190
# 5556     -6.548     1       0.0373       0.00288          0.001330    0.0631
# 5826     -6.798     0       0.0363       0.00454          0.000002    0.0335
# 5827     -5.911     1       0.0916       0.00957          0.000027    0.1210
# 5829     -6.744     1       0.0461       0.00593          0.000002    0.0361
# 6389     -5.412     1       0.0540       0.10300          0.000000    0.0913
# 6917     -5.414     1       0.1650       0.05610          0.000000    0.1480
# 6918     -6.114     1       0.1810       0.08710          0.000006    0.1480
# 6923     -7.417     1       0.0741       0.07090          0.005600    0.1060
# 9884     -6.471     0       0.1230       0.20400          0.000014    0.1260
# 9886     -6.684     1       0.1350       0.07130          0.000009    0.2130
# 9889    -10.178     0       0.0682       0.21600          0.000357    0.0911
# 9897     -6.237     1       0.0558       0.00845          0.000000    0.1080
# 9970     -4.899     1       0.2220       0.13300          0.000000    0.1020
# 11778    -4.143     1       0.0702       0.02910          0.000000    0.1120
# 12481    -4.137     1       0.0581       0.07200          0.000462    0.0906
# 12495    -5.617     1       0.0553       0.00929          0.000000    0.0637
# 12523   -10.345     1       0.5190       0.29800          0.000002    0.0812
# 13189    -7.176     1       0.0640       0.43300          0.000000    0.0862
#
#        valence    tempo  duration_ms
# 4136    0.5750   89.128       203440
# 4686    0.4690  129.969       230507
# 4982    0.8080  164.004       237747
# 5556    0.6760  104.011       231867
# 5826    0.6790   77.019       219720
# 5827    0.7500   85.984       193147
# 5829    0.6370   76.760       219720
# 6389    0.5700   95.997       231827
# 6917    0.9430  160.020       219200
# 6918    0.2950  170.157       211933
# 6923    0.4670  140.060       220440
# 9884    0.5060  128.070       211853
# 9886    0.4510   92.027       209680
# 9889    0.0499   95.045       232253
# 9897    0.1510  159.073       244827
# 9970    0.4960  160.090       189509
# 11778   0.6570  182.123       193040
# 12481   0.7390   95.037       152773
# 12495   0.7140   85.026       171360
# 12523   0.5410   92.875       170640
# 13189   0.4220  205.272       221307
#
# [21 rows x 22 columns]
